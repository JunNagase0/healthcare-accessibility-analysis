# %% [markdown]
# # 現状と進め方
# * DEAで都道府県の医療資源の活用の効率度合いを可視化。-nagase04
# * 都道府県の医療資源の特徴についてクラスター分析。-nagase05
# * 主成分分析によって特徴を明確にする。-nagase05
# * 空間的自己相関分析によって隣接する都道府県と資源構造が似ているか明確にした。-nagase05
# * 傾向スコアマッチングによって病床が多いほど医療費を増大させやすいことを明らかにした。（供給が需要を創出する。-医療経済学ローマーの法則）-nagase05
# * 傾向スコアマッチングの変数を医療費から入院費用に置き換えたところ、有意な結果は出ず。あくまで供給（病院中心の構造）は、需要（入院）だけをピンポイントで生み出すのではない。供給（病院中心の構造）は、需要（外来、検査、薬剤など、医療サービス全体）を創出していることが分かった。-nagase05
#
# ## できたら
# *
